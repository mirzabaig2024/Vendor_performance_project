# %% [markdown]
# # **Data Description**
# Dataset consists vendors information in various tables like
# * Purchases table
# * Purchase_Prices table
# * Vendor_Invoice table
# * Sales table

# %%
# impporting required libraries
from urllib.parse import quote_plus
import pandas as pd
from sqlalchemy import create_engine,text
import os
import math
import numpy as np

# %%
# Mysql Database connection
user = 'root'
password = quote_plus('Azmath@2024')
host = 'localhost'
port = 3306
database = 'inventory'
url = f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}"
engine = create_engine(url)
with engine.connect() as connection:
    result = connection.execute(text("SELECT 1"))
    print("Successfully connected:", result.scalar())
# Out:
# Successfully connected: 1

# %%
# Function to import CSV file into database
def importcsvfileintodatabase(tablename,engine,df):
    df.to_sql(tablename,con = engine,if_exists='replace',index=False)

# %%
# Function to read CSV files from a directory and import them into the database
def read_csvfile():

    path = r'C:\Users\Lenovo\OneDrive\Desktop\Project'

    for file in os.listdir(path):
        if file.endswith(".csv"):
                file_path = os.path.join(path, file)
                df = pd.read_csv(file_path)
                print(df.shape)
                file_name  = file[:-4]
                print(f"Importing {file_name} to database")
                #importcsvfileintodatabase(file_name,engine,file_path)

read_csvfile()
# Out:
# (206529, 9)
# Importing begin_inventory to database
# (224489, 9)
# Importing end_inventory to database
# (2372474, 16)
# Importing purchases to database
# (12261, 9)
# Importing purchase_prices to database
# (12825363, 14)
# Importing sales to database
# (5543, 10)
# Importing vendor_invoice to database

# %%
# Query to list all tables in the inventory database
query = '''select TABLE_NAME as NAME from information_schema.tables where TABLE_SCHEMA = 'inventory' AND TABLE_TYPE = 'BASE TABLE' '''
tables = pd.read_sql(query,engine)
print(tables)
# Out:
#               NAME
# 0  begin_inventory
# 1    end_inventory
# 2    final_summary
# 3  purchase_prices
# 4        purchases
# 5            sales
# 6   vendor_invoice

# %%
# Displaying count and first 5 rows of each table in the database
for table in tables ['NAME']:
    print('-'*20 ,{table} ,'-'*20)
    query = f'''select count(*) from {table}'''
    print("Count a table : ",pd.read_sql(query,engine))
    display(pd.read_sql(f'select * from {table} limit 5',engine))
# Out:
# -------------------- {'begin_inventory'} --------------------
# Count a table :     count(*)
# 0    206529
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# 1  750mL       7  10.99  2024-01-01
# 2  750mL       6  36.99  2024-01-01
# 3  750mL       3  38.99  2024-01-01
# 4  750mL       6  34.99  2024-01-01
# -------------------- {'end_inventory'} --------------------
# Count a table :     count(*)
# 0    224489
# ...

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %%
# Analyzing Purchases table
query_p = 'select * from purchases;'
purchase_summary = pd.read_sql(query_p,engine)
purchase_summary
# Out:
#                      Quantity   Dollars
# Brand PurchasePrice
# 58    9.28               3550  32944.00
# 60    7.40               1633  12084.20
# 61    10.60               312   3307.20
# 62    28.67              3200  91744.00
# 63    30.46              2855  86963.30
# ...                       ...       ...
# 90089 77.92                32   2493.44
# 90090 448.27                6   2689.62
# 90604 78.42               118   9253.56
# 90609 17.00               321   5457.00
# 90631 12.74              1938  24690.12
#
# [10664 rows x 2 columns]

# %%
# Analyzing Sales table
query_p = 'select * from sales;'
sales = pd.read_sql(query_p,engine)
sales
# Out:
#                   InventoryId  Store  Brand                 Description  \
# 0         1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 1         1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 2         1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 3         1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 4         1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack
# ...                       ...    ...    ...                         ...
# 12825358      9_BLACKPOOL_984      9    984      Patron XO Cafe Liqueur
# 12825359      9_BLACKPOOL_984      9    984      Patron XO Cafe Liqueur
# 12825360      9_BLACKPOOL_984      9    984      Patron XO Cafe Liqueur
# 12825361      9_BLACKPOOL_984      9    984      Patron XO Cafe Liqueur
# 12825362      9_BLACKPOOL_984      9    984      Patron XO Cafe Liqueur
#
#                 Size  SalesQuantity  SalesDollars  SalesPrice   SalesDate  \
# ...

# %%
# Analyzing Purchase Prices table
query_pp = 'select * from purchase_prices;'
purchase_price = pd.read_sql(query_pp,engine)
purchase_price
# Out:
#        Brand                   Description  Price    Size Volume  \
# 0         58   Gekkeikan Black & Gold Sake  12.99   750mL    750
# 1         62      Herradura Silver Tequila  36.99   750mL    750
# 2         63    Herradura Reposado Tequila  38.99   750mL    750
# 3         72          No. 3 London Dry Gin  34.99   750mL    750
# 4         75     Three Olives Tomato Vodka  14.99   750mL    750
# ...      ...                           ...    ...     ...    ...
# 12256  44917     Ferreira 10-Yr Tawny Port  24.99   750mL    750
# 12257  44944     Sanford Santa Rita Pnt Nr  22.99   750mL    750
# 12258  45016  Neal One Lane Bridg Cab Svgn  93.99   750mL    750
# 12259  46011       Folonari Pnt Nr Venezie  12.99  1500ml   1500
# 12260  46964     Calera Viognier Mt Harlan  35.99   750mL    750
#
#        Classification  PurchasePrice  VendorNumber  \
# 0                   1           9.28          8320
# 1                   1          28.67          1128
# ...

# %%
# Analyzing Vendor Invoice table
query_v = 'select * from vendor_invoice;'
vendor_invoice = pd.read_sql(query_v,engine)

# %%
# Checking for the number of unique purchase orders
purchase_summary.columns
purchase_summary['PONumber'].nunique()
# Out:
# 5543

# %%
# Checking for the number of unique purchase orders in Vendor Invoice table
vendor_invoice ['PONumber'].nunique()
# Out:
# 5543

# %%
vendor_invoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
# Cost of Freight(transportation cost)
vendor_invoice['Freight']
# Out:
# 0          3.47
# 1          8.57
# 2          4.61
# 3       2935.20
# 4        429.20
#          ...
# 5538       8.60
# 5539     186.50
# 5540     932.95
# 5541     819.54
# 5542      16.60
# Name: Freight, Length: 5543, dtype: float64

# %%
# Summarizing Freight cost by each Vendor
Freight_summary = pd.read_sql('select vendornumber,sum(freight) from vendor_invoice group by vendornumber;',engine)
Freight_summary
# Out:
#      vendornumber  sum(freight)
# 0             105         62.39
# 1            4466        793.91
# 2             388        211.74
# 3             480      89286.27
# 4             516       8510.41
# ..            ...           ...
# 121        201359          0.09
# 122          4901          0.72
# 123         90059         74.84
# 124          5083         10.68
# 125            54          0.48
#
# [126 rows x 2 columns]

# %%
purchase_summary.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification'],
#       dtype='object')

# %%
purchase_price.columns
# Out:
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %%
# Joining Purchases and Purchase Prices table to get more insights
with engine.begin() as conn:
    result1 = conn.execute(text("SET SESSION sql_mode=(SELECT REPLACE(@@sql_mode,'ONLY_FULL_GROUP_BY',''))"))
    print("Successfully connected:")
    query = 'select p.brand,p.vendorNumber,p.vendorname,p.purchaseprice,p.description,pp.price,pp.volume,sum(p.quantity) As total_quantity,sum(p.dollars) from purchases p join purchase_prices pp on p.brand = pp.brand where p.purchaseprice>0 group by p.vendornumber,p.vendorname,p.brand order by total_quantity asc ;'
    vendor_purchasedetails = pd.read_sql(query,conn)
vendor_purchasedetails
# Out:
# Successfully connected:
#        brand  vendorNumber                   vendorname  purchaseprice  \
# 0      16531         10754  PERFECTA WINES                       14.09
# 1      36069         10754  PERFECTA WINES                       51.00
# 2       5181           480  BACARDI USA INC                      23.99
# 3      18458          4425        MARTIGNETTI COMPANIES           6.80
# 4      17444          5612  MILTONS DISTRIBUTING CO               5.22
# ...      ...           ...                          ...            ...
# 10687   6570         10000  MAJESTIC FINE WINES                   6.77
# 10688   3606          3960  DIAGEO NORTH AMERICA INC              0.74
# 10689   5111          8004  SAZERAC CO INC                        0.72
# 10690   1892          3960  DIAGEO NORTH AMERICA INC              0.72
# 10691   8111          3960  DIAGEO NORTH AMERICA INC              0.77
#
#                         description   price volume  total_quantity  \
# ...

# %%
sales.columns
# Out:
# Index(['vendorno', 'brand', 'totalsaledollar', 'totalpurchase',
#        'totalsalesquantity', 'totalecisetax'],
#       dtype='object')

# %%
# Summarizing Sales by each Vendor and Brand
query = 'with freight_summary as(select vendornumber,sum(freight) as freigthcost from vendor_invoice group by vendornumber), purchase_summary as(select p.brand,p.vendorNumber,p.vendorname,p.description,p.purchaseprice,pp.price as actualprice,pp.volume,sum(p.quantity) As totalpurchasequantity,sum(p.dollars) as totalpurchasedollar from purchases p join purchase_prices pp on p.brand = pp.brand where p.purchaseprice > 0 group by p.vendornumber,p.vendorname,p.brand ),' \
' sales_summary as(select vendorno,brand,sum(salesdollars) as totalsaledollar, sum(salesprice) as totalpurchase,sum(salesquantity) as totalsalesquantity , sum(excisetax) as totalecisetax from sales  group by vendorno , brand ) ' \
'select ps.vendornumber,ps.vendorname,ps.brand,ps.description,ps.purchaseprice,ps.actualprice,ps.volume,ps.totalpurchasedollar ,ps.totalpurchasequantity,ss.totalsalesquantity,ss.totalsaledollar,ss.totalecisetax,fs.freigthcost from purchase_summary ps left join sales_summary ss on ps.vendornumber = ss.vendorno and ps.brand = ss.brand left join freight_summary fs on ps.vendornumber = fs.vendornumber order by totalpurchasedollar asc; '
final_summary = pd.read_sql(query,engine)
final_summary
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# ...

# %%
final_summary.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 final_summary.shape
#
# NameError: name 'final_summary' is not defined

# %% [markdown]
# # **Exploratory Data Analysis (EDA) of Final_Summary Table**
#     Analyzing and Cleaning the Final_Summary Table

# %%
# finding the null values in the final_summary table
final_summary.isnull().sum() '''their are 178 null values in the final_summary table'''
# Out:
# vendornumber               0
# vendorname                 0
# brand                      0
# description                0
# purchaseprice              0
# actualprice                0
# volume                     0
# totalpurchasedollar        0
# totalpurchasequantity      0
# totalsalesquantity       178
# totalsaledollar          178
# totalecisetax            178
# freigthcost                0
# dtype: int64

# %%
final_summary ['volume'] = final_summary ['volume'].astype('float') # initially volume datatype is objection with this query we change it into float

# %%
#finding the unique vendor names in the final_summary table
final_summary ['vendorname'].unique()
# Out:
# array(['PROXIMO SPIRITS INC.       ', 'DIAGEO NORTH AMERICA INC   ',
#        'HEAVEN HILL DISTILLERIES   ', 'SAZERAC CO INC             ',
#        'WINE GROUP INC             ', 'VINILANDIA USA             ',
#        'PALM BAY INTERNATIONAL INC ', 'MARTIGNETTI COMPANIES',
#        'STE MICHELLE WINE ESTATES  ', 'ULTRA BEVERAGE COMPANY LLP ',
#        'BANFI PRODUCTS CORP        ', 'MILTONS DISTRIBUTING CO    ',
#        'M S WALKER INC             ', 'JIM BEAM BRANDS COMPANY    ',
#        'PINE STATE TRADING CO      ', 'THE IMPORTED GRAPE LLC     ',
#        'SOUTHERN WINE & SPIRITS NE ', 'DIAGEO CHATEAU ESTATE WINES',
#        'LUXCO INC                  ', 'KOBRAND CORPORATION        ',
#        'BACARDI USA INC            ', 'MHW LTD                    ',
#        'STATE WINE & SPIRITS   ', 'PERFECTA WINES             ',
#        'SAZERAC NORTH AMERICA INC. ', 'Circa Wines                ',
#        'VINEYARD BRANDS INC        ', 'CRUSH WINES                ',
# ...

# %%
final_summary ['vendorname'] = final_summary ['vendorname'].str.strip() #initially there some space b/t them with using this query we removed the space b/t them

# %%
final_summary.fillna(0,inplace= True) #replacing missing value 178 with 0

# %%
final_summary.columns
# Out:
# Index(['vendornumber', 'vendorname', 'brand', 'description', 'purchaseprice',
#        'actualprice', 'volume', 'totalpurchasedollar', 'totalpurchasequantity',
#        'totalsalesquantity', 'totalsaledollar', 'totalecisetax',
#        'freigthcost'],
#       dtype='object')

# %%
final_summary
# Out:
#        vendornumber                vendorname  brand  \
# 0              7245      PROXIMO SPIRITS INC.   3065
# 1              3960  DIAGEO NORTH AMERICA INC   6127
# 2              3924  HEAVEN HILL DISTILLERIES   9123
# 3              8004            SAZERAC CO INC   5683
# 4              9815            WINE GROUP INC   8527
# ...             ...                       ...    ...
# 10687          3960  DIAGEO NORTH AMERICA INC   3545
# 10688          3960  DIAGEO NORTH AMERICA INC   4261
# 10689         17035         PERNOD RICARD USA   8068
# 10690          4425     MARTIGNETTI COMPANIES   3405
# 10691          1128         BROWN-FORMAN CORP   1233
#
#                        description  purchaseprice  actualprice  volume  \
# 0         Three Olives Grape Vodka           0.71         0.99    50.0
# 1      The Club Strawbry Margarita           1.47         1.99   200.0
# 2                  Deep Eddy Vodka           0.74         0.99    50.0
# ...

# %%
# Calculating Gross Profit and adding new column Gross_Profit
final_summary ['Gross_Profit'] = final_summary['totalsaledollar'] - final_summary['totalpurchasedollar']

# %%
# calculating Profit Margin and adding new column ProfitMargin
final_summary ['ProfitMargin'] = (final_summary['Gross_Profit']/final_summary['totalsaledollar'])*100

# %%
# calculating Stock Turnover and adding new column StockTurnover
final_summary ['stockturnover'] = final_summary['totalsalesquantity']/final_summary['totalpurchasequantity']

# %%
# calculating Sales to Purchase Ratio and adding new column salestopurchaseratio
final_summary ['salestopurchaseratio'] = final_summary ['totalsaledollar']/final_summary['totalpurchasedollar']

# %%
# replacing inf and -inf values with a large number to  import in mysql database
final_summary.replace([np.inf,-np.inf],1e300,inplace=True)

# %%
# importing final_summary table into mysql database
final_summary.to_sql('final_summary',con=engine,if_exists='replace',index=False)
# Out:
# 10692
